# %%
import pandas as pd

# %%
df_vagas = pd.read_excel('Vagas.xlsx')
df_vagas.columns
# Out:
# Index(['Unnamed: 0', 'LOJA', 'FUNÇÃO', 'VAGAS '], dtype='object')

# %%
administrativo = [
    "ANALISTA DE CREDITO",
    "COORDENADOR ADMINISTRATIVO",
    "COORDENADOR ADMINISTRATIVO II",
    "ASSISTENTE ADMINISTRATIVO",
    "AUXILIAR ADMINISTRATIVO",
    "CAIXA",
    "ASSESSOR DE SERVICOS",
]

limpeza=["AUXILIAR DE SERVICOS GERAIS",
    "AUXILIAR DE SERVICOS GERAIS II",]

estoque = [
    "AUXILIAR DE ESTOQUES",
    "AUXILIAR DE MONTAGEM",
    "CONFERENTE CARGA",
    "CONFERENTE DE EXPEDICAO",
    "CONFERENTE I",
    "ENCARREGADO DE CONFERENCIA",
    "ENCARREGADO DE EXPEDICAO",
    "MONTADOR MOVEIS",
    "MOTORISTA",
    "OPERADOR DE EMPILHADEIRA",
    "COORDENADOR DE DEPOSITO",
    "COORDENADOR DE ESTOQUE",
    "ESTOQUISTA",
    "SUPERVISOR DE ESTOQUE",
    "GERENTE DE ESTOQUE",
    "AUXILIAR OPERACIONAL"
]

vendas = [
    "CONSULTOR DE VENDAS",
    "CONSULTOR DE VENDAS OUTLET",
    "COORDENADOR DE VENDAS",
    "SUPERVISOR DE VENDAS",
    "GERENTE DE VENDAS",
    "VENDEDOR(A)",
    "VENDEDOR EXTERNO",
    "CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO",
    "CONSULTOR PROJETISTA DE MOVEIS",
    "CONSULTOR ESPECIALISTA EM TINTAS",
    "AUXILIAR PROJETISTA",
]

# %%
df_vagas.columns = df_vagas.columns.str.strip()
df_vagas = df_vagas[~df_vagas['VAGAS'].isin([0, df_vagas['VAGAS'].max()])]

# %%
df_vagas_abertas = df_vagas[df_vagas['VAGAS'] < 0]
df_vagas = df_vagas[df_vagas['VAGAS'] > 0]

# %%
df_vagas_abertas

for funcao in df_vagas:
    if funcao['LOJA'] == df_vagas_abertas['LOJA']
# Out:
#      Unnamed: 0 LOJA                                            FUNÇÃO  VAGAS
# 5           NaN    9  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# 12          NaN   15                              AUXILIAR DE ESTOQUES     -1
# 19          NaN   16                              AUXILIAR OPERACIONAL     -1
# 28          NaN   21                              SUPERVISOR DE VENDAS     -1
# 30          NaN   21  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# 43          NaN   29                       AUXILIAR DE SERVICOS GERAIS     -1
# 58          NaN   49                               ANALISTA DE CREDITO     -1
# 88          NaN   75  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# 163         NaN  187  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# 166         NaN  190  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# 174         NaN  198  CONSULTOR ESPECIALISTA EM MATERIAL DE CONSTRUCAO     -1
# ...
